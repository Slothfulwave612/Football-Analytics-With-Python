# %%
import pandas as pd

# %%
data = pd.read_html("https://fbref.com/en/comps/Big5/shooting/players/Big-5-European-Leagues-Stats#stats_shooting", skiprows=0)[0]

# %%
def fow(x):
    if "FW" in x.split(','):
        return True
    return False

# %%
data
# Out:
#      Unnamed: 0_level_0   Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                      Rk               Player             Nation
# 0                     1        Ismael Aaneba             fr FRA
# 1                     2  Patrick van Aanholt             nl NED
# 2                     3          Issah Abbas             gh GHA
# 3                     4     Yunis Abdelhamid             ma MAR
# 4                     5        Sabit Abdulai             gh GHA
# ...                 ...                  ...                ...
# 2930               2819         Steven Zuber             ch SUI
# 2931               2820     Martín Zubimendi             es ESP
# 2932               2821      Martin Ødegaard             no NOR
# 2933               2822      Martin Ødegaard             no NOR
# 2934               2823        Filip Đuričić             rs SRB
#
#      Unnamed: 3_level_0 Unnamed: 4_level_0  Unnamed: 5_level_0  \
#                     Pos              Squad                Comp
# ...

# %%
data = data.loc[data["fow"] == True]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'fow'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-115-e99963ce82c3> in <module>
# ...

# %%
xg = data["Expected"]["xG"].astype(float).values

# %%
mean_val, std_val = np.nanmean(xg), np.nanstd(xg)

# %%
mean_val, std_val
# Out:
# (3.5732161323681493, 4.312013508111353)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
np.percentile(a, 50

# %%
sns.displot(xg, kind="kde", bw_adjust=2)
